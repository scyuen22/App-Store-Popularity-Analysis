# %% [markdown]
# # App Store Analysis Project

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Open and Explore Datasets

# %% [markdown]
# Read datasets for Apple Store and Google Play Store

# %%
apple = pd.read_csv('AppleStore.csv')
google = pd.read_csv('googleplaystore.csv')

# %% [markdown]
# Dataset Exploration
# - Shape
# - Headings
# - Datatypes

# %%
def explore(dataset, title):
    print(title)
    print(dataset.shape)
    print(dataset.columns)
    print(dataset.dtypes)

# %% [markdown]
# Explore Apple Store Dataset

# %%
explore(apple, 'Apple')
# Out:
# Apple
# (7197, 17)
# Index(['Unnamed: 0', 'id', 'track_name', 'size_bytes', 'currency', 'price',
#        'rating_count_tot', 'rating_count_ver', 'user_rating',
#        'user_rating_ver', 'ver', 'cont_rating', 'prime_genre',
#        'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic'],
#       dtype='object')
# Unnamed: 0            int64
# id                    int64
# track_name           object
# size_bytes            int64
# currency             object
# price               float64
# rating_count_tot      int64
# rating_count_ver      int64
# user_rating         float64
# user_rating_ver     float64
# ver                  object
# cont_rating          object
# prime_genre          object
# sup_devices.num       int64
# ipadSc_urls.num       int64
# lang.num              int64
# vpp_lic               int64
# dtype: object

# %%
apple.head()
# Out:
#           id                                         track_name  size_bytes  \
# 0  281656475                                    PAC-MAN Premium   100788224
# 1  281796108                          Evernote - stay organized   158578688
# 2  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts   100524032
# 3  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...   128512000
# 4  282935706                                              Bible    92774400
#
#   currency  price  rating_count_tot  rating_count_ver  user_rating  \
# 0      USD   3.99             21292                26          4.0
# 1      USD   0.00            161065                26          4.0
# 2      USD   0.00            188583              2822          3.5
# 3      USD   0.00            262241               649          4.0
# 4      USD   0.00            985920              5320          4.5
#
#    user_rating_ver     ver cont_rating   prime_genre  sup_devices.num  \
# 0              4.5   6.3.5          4+         Games               38
# 1              3.5   8.2.2          4+  Productivity               37
# 2              4.5   5.0.0          4+       Weather               37
# 3              4.5  5.10.0         12+      Shopping               37
# 4              5.0   7.5.1          4+     Reference               37
#
#    ipadSc_urls.num  lang.num  vpp_lic
# 0                5        10        1
# 1                5        23        1
# 2                5         3        1
# 3                5         9        1
# 4                5        45        1

# %% [markdown]
# Remove row # column

# %%
apple.drop("Unnamed: 0", axis=1, inplace=True)

# %% [markdown]
# Unique Values in Categorical Columns

# %%
apple_cat = ['currency','cont_rating','prime_genre']
for cat in apple_cat:
    print(cat)
    print(apple[cat].unique())
# Out:
# currency
# ['USD']
# cont_rating
# ['4+' '12+' '17+' '9+']
# prime_genre
# ['Games' 'Productivity' 'Weather' 'Shopping' 'Reference' 'Finance' 'Music'
#  'Utilities' 'Travel' 'Social Networking' 'Sports' 'Business'
#  'Health & Fitness' 'Entertainment' 'Photo & Video' 'Navigation'
#  'Education' 'Lifestyle' 'Food & Drink' 'News' 'Book' 'Medical' 'Catalogs']

# %% [markdown]
# Explore Google Play Store Dataset

# %%
explore(google, 'Google Play')
# Out:
# Google Play
# (10841, 13)
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
google.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %% [markdown]
# Convert datatypes for Reviews, Price

# %%
google['Reviews'] = google['Reviews'].astype(str).astype(int)

# %%
google['Price'] = google['Price'].str.replace('$','').astype(float)

# %% [markdown]
# Updated Column Datatypes

# %%
google.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int32
# Size               object
# Installs           object
# Type               object
# Price             float64
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %% [markdown]
# Drop row 10472 due to unmatching columns

# %%
google.loc[google['Price'] == 'Everyone']
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
i = google[(google.App == 'Life Made WI-Fi Touchscreen Photo Frame')].index

# %%
google.drop(i, axis=0, inplace=True)

# %% [markdown]
# Updated Google Play Dataset Dimensions

# %%
google.shape
# Out:
# (10840, 13)

# %% [markdown]
# Unique Variables in Categorical Columns

# %%
google_cat = ['Category','Type','Content Rating','Genres']
for cat in google_cat:
    print(cat)
    print(google[cat].unique())
# Out:
# Category
# ['ART_AND_DESIGN' 'AUTO_AND_VEHICLES' 'BEAUTY' 'BOOKS_AND_REFERENCE'
#  'BUSINESS' 'COMICS' 'COMMUNICATION' 'DATING' 'EDUCATION' 'ENTERTAINMENT'
#  'EVENTS' 'FINANCE' 'FOOD_AND_DRINK' 'HEALTH_AND_FITNESS' 'HOUSE_AND_HOME'
#  'LIBRARIES_AND_DEMO' 'LIFESTYLE' 'GAME' 'FAMILY' 'MEDICAL' 'SOCIAL'
#  'SHOPPING' 'PHOTOGRAPHY' 'SPORTS' 'TRAVEL_AND_LOCAL' 'TOOLS'
#  'PERSONALIZATION' 'PRODUCTIVITY' 'PARENTING' 'WEATHER' 'VIDEO_PLAYERS'
#  'NEWS_AND_MAGAZINES' 'MAPS_AND_NAVIGATION']
# Type
# ['Free' 'Paid' nan]
# Content Rating
# ['Everyone' 'Teen' 'Everyone 10+' 'Mature 17+' 'Adults only 18+' 'Unrated']
# Genres
# ['Art & Design' 'Art & Design;Pretend Play' 'Art & Design;Creativity'
#  'Art & Design;Action & Adventure' 'Auto & Vehicles' 'Beauty'
#  'Books & Reference' 'Business' 'Comics' 'Comics;Creativity'
#  'Communication' 'Dating' 'Education;Education' 'Education'
#  'Education;Creativity' 'Education;Music & Video'
#  'Education;Action & Adventure' 'Education;Pretend Play'
#  'Education;Brain Games' 'Entertainment' 'Entertainment;Music & Video'
#  'Entertainment;Brain Games' 'Entertainment;Creativity' 'Events' 'Finance'
#  'Food & Drink' 'Health & Fitness' 'House & Home' 'Libraries & Demo'
#  'Lifestyle' 'Lifestyle;Pretend Play' 'Adventure;Action & Adventure'
#  'Arcade' 'Casual' 'Card' 'Casual;Pretend Play' 'Action' 'Strategy'
#  'Puzzle' 'Sports' 'Music' 'Word' 'Racing' 'Casual;Creativity'
#  'Casual;Action & Adventure' 'Simulation' 'Adventure' 'Board' 'Trivia'
#  'Role Playing' 'Simulation;Education' 'Action;Action & Adventure'
#  'Casual;Brain Games' 'Simulation;Action & Adventure'
#  'Educational;Creativity' 'Puzzle;Brain Games' 'Educational;Education'
#  'Card;Brain Games' 'Educational;Brain Games' 'Educational;Pretend Play'
#  'Entertainment;Education' 'Casual;Education' 'Music;Music & Video'
#  'Racing;Action & Adventure' 'Arcade;Pretend Play'
#  'Role Playing;Action & Adventure' 'Simulation;Pretend Play'
#  'Puzzle;Creativity' 'Sports;Action & Adventure'
#  'Educational;Action & Adventure' 'Arcade;Action & Adventure'
#  'Entertainment;Action & Adventure' 'Puzzle;Action & Adventure'
#  'Strategy;Action & Adventure' 'Music & Audio;Music & Video'
#  'Health & Fitness;Education' 'Adventure;Education' 'Board;Brain Games'
#  'Board;Action & Adventure' 'Board;Pretend Play' 'Casual;Music & Video'
#  'Role Playing;Pretend Play' 'Entertainment;Pretend Play'
#  'Video Players & Editors;Creativity' 'Card;Action & Adventure' 'Medical'
#  'Social' 'Shopping' 'Photography' 'Travel & Local'
#  'Travel & Local;Action & Adventure' 'Tools' 'Tools;Education'
#  'Personalization' 'Productivity' 'Parenting' 'Parenting;Music & Video'
#  'Parenting;Education' 'Parenting;Brain Games' 'Weather'
#  'Video Players & Editors' 'Video Players & Editors;Music & Video'
#  'News & Magazines' 'Maps & Navigation'
#  'Health & Fitness;Action & Adventure' 'Educational' 'Casino'
#  'Adventure;Brain Games' 'Trivia;Education' 'Lifestyle;Education'
#  'Books & Reference;Creativity' 'Books & Reference;Education'
#  'Puzzle;Education' 'Role Playing;Education' 'Role Playing;Brain Games'
#  'Strategy;Education' 'Racing;Pretend Play' 'Communication;Creativity'
#  'Strategy;Creativity']

# %% [markdown]
# Find row with null Type and fill cell

# %%
google[google['Type'].isnull()]
# Out:
#                             App Category  Rating  Reviews                Size  \
# 9148  Command & Conquer: Rivals   FAMILY     NaN        0  Varies with device
#
#      Installs Type  Price Content Rating    Genres   Last Updated  \
# 9148        0  NaN    0.0   Everyone 10+  Strategy  June 28, 2018
#
#              Current Ver         Android Ver
# 9148  Varies with device  Varies with device

# %%
google.at[9148, 'Type'] = 'Free'

# %%
google.loc[9148]
# Out:
# App               Command & Conquer: Rivals
# Category                             FAMILY
# Rating                                  NaN
# Reviews                                   0
# Size                     Varies with device
# Installs                                  0
# Type                                   Free
# Price                                   0.0
# Content Rating                 Everyone 10+
# Genres                             Strategy
# Last Updated                  June 28, 2018
# Current Ver              Varies with device
# Android Ver              Varies with device
# Name: 9148, dtype: object

# %% [markdown]
# ## Find and Remove Duplicates

# %% [markdown]
# Apple Store Dataset

# %%
apple.duplicated(subset = ['id']).any()
# Out:
# False

# %%
apple.duplicated(subset = ['track_name']).any()
# Out:
# True

# %%
apple.duplicated(subset=['track_name']).sum()
# Out:
# 2

# %%
apple.loc[apple.duplicated(subset=['track_name']) == True]
# Out:
#               id           track_name  size_bytes currency  price  \
# 5603  1089824278    VR Roller Coaster   240964608      USD    0.0
# 7128  1178454060  Mannequin Challenge    59572224      USD    0.0
#
#       rating_count_tot  rating_count_ver  user_rating  user_rating_ver    ver  \
# 5603                67                44          3.5              4.0   0.81
# 7128               105                58          4.0              4.5  1.0.1
#
#      cont_rating prime_genre  sup_devices.num  ipadSc_urls.num  lang.num  \
# 5603          4+       Games               38                0         1
# 7128          4+       Games               38                5         1
#
#       vpp_lic
# 5603        1
# 7128        1

# %%
apple.loc[apple['track_name'] == 'VR Roller Coaster']
# Out:
#               id         track_name  size_bytes currency  price  \
# 3319   952877179  VR Roller Coaster   169523200      USD    0.0
# 5603  1089824278  VR Roller Coaster   240964608      USD    0.0
#
#       rating_count_tot  rating_count_ver  user_rating  user_rating_ver    ver  \
# 3319               107               102          3.5              3.5  2.0.0
# 5603                67                44          3.5              4.0   0.81
#
#      cont_rating prime_genre  sup_devices.num  ipadSc_urls.num  lang.num  \
# 3319          4+       Games               37                5         1
# 5603          4+       Games               38                0         1
#
#       vpp_lic
# 3319        1
# 5603        1

# %%
apple.loc[apple['track_name'] == 'Mannequin Challenge']
# Out:
#               id           track_name  size_bytes currency  price  \
# 7092  1173990889  Mannequin Challenge   109705216      USD    0.0
# 7128  1178454060  Mannequin Challenge    59572224      USD    0.0
#
#       rating_count_tot  rating_count_ver  user_rating  user_rating_ver    ver  \
# 7092               668                87          3.0              3.0    1.4
# 7128               105                58          4.0              4.5  1.0.1
#
#      cont_rating prime_genre  sup_devices.num  ipadSc_urls.num  lang.num  \
# 7092          9+       Games               37                4         1
# 7128          4+       Games               38                5         1
#
#       vpp_lic
# 7092        1
# 7128        1

# %% [markdown]
# Google Play Dataset

# %%
google.duplicated().sum()
# Out:
# 483

# %%
google.loc[google.duplicated() == True]
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10768                                             AAFP       MEDICAL     3.8
#
#        Reviews                Size      Installs  Type  Price Content Rating  \
# 229      80805  Varies with device    5,000,000+  Free    0.0       Everyone
# 236     159872  Varies with device   10,000,000+  Free    0.0       Everyone
# 239      70991  Varies with device    5,000,000+  Free    0.0       Everyone
# 256      31614                 37M   10,000,000+  Free    0.0       Everyone
# 261       6989  Varies with device    1,000,000+  Free    0.0       Everyone
# ...        ...                 ...           ...   ...    ...            ...
# 8643    404610  Varies with device   10,000,000+  Free    0.0       Everyone
# 8654     25370  Varies with device    1,000,000+  Free    0.0       Everyone
# 8658   2401017  Varies with device  100,000,000+  Free    0.0       Everyone
# 10049      123                 86M       10,000+  Free    0.0       Everyone
# 10768       63                 24M       10,000+  Free    0.0       Everyone
#
#              Genres       Last Updated         Current Ver         Android Ver
# 229        Business  February 26, 2018  Varies with device        4.0.3 and up
# 236        Business      July 31, 2018  Varies with device  Varies with device
# 239        Business      July 24, 2018    2.19.0.204537701          4.4 and up
# 256        Business      July 20, 2018      4.1.28165.0716          4.0 and up
# 261        Business      July 16, 2018           4.3.0.508          4.4 and up
# ...             ...                ...                 ...                 ...
# 8643   Productivity      April 6, 2018  Varies with device  Varies with device
# 8654   Productivity     August 6, 2018  Varies with device  Varies with device
# 8658   Productivity      June 27, 2018  Varies with device  Varies with device
# 10049       Medical       June 1, 2018              0.6.88          5.0 and up
# 10768       Medical      June 22, 2018               2.3.1          5.0 and up
#
# [483 rows x 13 columns]

# %%
google.drop_duplicates(inplace=True)

# %%
google.duplicated().sum()
# Out:
# 0

# %%
google.duplicated(subset=['App']).sum()
# Out:
# 698

# %%
google.loc[google.duplicated(subset=['App']) == True]
# Out:
#                                             App       Category  Rating  \
# 285                Quick PDF Scanner + OCR FREE       BUSINESS     4.2
# 293      OfficeSuite : Free Office + PDF Editor       BUSINESS     4.3
# 294                                       Slack       BUSINESS     4.4
# 382    Messenger – Text and Video Chat for Free  COMMUNICATION     4.0
# 383               imo free video calls and chat  COMMUNICATION     4.3
# ...                                         ...            ...     ...
# 10647                         Motorola FM Radio  VIDEO_PLAYERS     3.9
# 10715                        FarmersOnly Dating         DATING     3.0
# 10720        Firefox Focus: The privacy browser  COMMUNICATION     4.4
# 10730                               FP Notebook        MEDICAL     4.5
# 10753            Slickdeals: Coupons & Shopping       SHOPPING     4.5
#
#         Reviews                Size        Installs  Type  Price  \
# 285       80804  Varies with device      5,000,000+  Free    0.0
# 293     1002859                 35M    100,000,000+  Free    0.0
# 294       51510  Varies with device      5,000,000+  Free    0.0
# 382    56646578  Varies with device  1,000,000,000+  Free    0.0
# 383     4785988                 11M    500,000,000+  Free    0.0
# ...         ...                 ...             ...   ...    ...
# 10647     54815  Varies with device    100,000,000+  Free    0.0
# 10715      1145                1.4M        100,000+  Free    0.0
# 10720     36981                4.0M      1,000,000+  Free    0.0
# 10730       410                 60M         50,000+  Free    0.0
# 10753     33599                 12M      1,000,000+  Free    0.0
#
#       Content Rating                   Genres       Last Updated  \
# 285         Everyone                 Business  February 26, 2018
# 293         Everyone                 Business     August 2, 2018
# 294         Everyone                 Business     August 2, 2018
# 382         Everyone            Communication     August 1, 2018
# 383         Everyone            Communication       June 8, 2018
# ...              ...                      ...                ...
# 10647       Everyone  Video Players & Editors        May 2, 2018
# 10715     Mature 17+                   Dating  February 25, 2016
# 10720       Everyone            Communication       July 6, 2018
# 10730       Everyone                  Medical     March 24, 2018
# 10753       Everyone                 Shopping      July 30, 2018
#
#               Current Ver         Android Ver
# 285    Varies with device        4.0.3 and up
# 293             9.7.14188          4.1 and up
# 294    Varies with device  Varies with device
# 382    Varies with device  Varies with device
# 383      9.8.000000010501          4.0 and up
# ...                   ...                 ...
# 10647  Varies with device  Varies with device
# 10715                 2.2          4.0 and up
# 10720                 5.2          5.0 and up
# 10730           2.1.0.372          4.4 and up
# 10753                 3.9          4.4 and up
#
# [698 rows x 13 columns]

# %%
google.loc[google['App'] == 'Slack']
# Out:
#        App  Category  Rating  Reviews                Size    Installs  Type  \
# 240  Slack  BUSINESS     4.4    51507  Varies with device  5,000,000+  Free
# 294  Slack  BUSINESS     4.4    51510  Varies with device  5,000,000+  Free
#
#      Price Content Rating    Genres    Last Updated         Current Ver  \
# 240    0.0       Everyone  Business  August 2, 2018  Varies with device
# 294    0.0       Everyone  Business  August 2, 2018  Varies with device
#
#             Android Ver
# 240  Varies with device
# 294  Varies with device

# %%
google.drop_duplicates(subset=['App'], inplace=True)

# %%
google.duplicated(subset=['App']).sum()
# Out:
# 0

# %% [markdown]
# ## Separate Free Apps

# %%
apple_free = apple.loc[apple['price'] == 0]

# %%
apple_free.head()
# Out:
#           id                                         track_name  size_bytes  \
# 1  281796108                          Evernote - stay organized   158578688
# 2  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts   100524032
# 3  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...   128512000
# 4  282935706                                              Bible    92774400
# 6  283646709             PayPal - Send and request money safely   227795968
#
#   currency  price  rating_count_tot  rating_count_ver  user_rating  \
# 1      USD    0.0            161065                26          4.0
# 2      USD    0.0            188583              2822          3.5
# 3      USD    0.0            262241               649          4.0
# 4      USD    0.0            985920              5320          4.5
# 6      USD    0.0            119487               879          4.0
#
#    user_rating_ver     ver cont_rating   prime_genre  sup_devices.num  \
# 1              3.5   8.2.2          4+  Productivity               37
# 2              4.5   5.0.0          4+       Weather               37
# 3              4.5  5.10.0         12+      Shopping               37
# 4              5.0   7.5.1          4+     Reference               37
# 6              4.5  6.12.0          4+       Finance               37
#
#    ipadSc_urls.num  lang.num  vpp_lic
# 1                5        23        1
# 2                5         3        1
# 3                5         9        1
# 4                5        45        1
# 6                0        19        1

# %%
apple_free.shape
# Out:
# (4056, 16)

# %%
google_free = google.loc[google['Price'] == 0]

# %%
google_free.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size     Installs  Type  Price Content Rating  \
# 0      159   19M      10,000+  Free    0.0       Everyone
# 1      967   14M     500,000+  Free    0.0       Everyone
# 2    87510  8.7M   5,000,000+  Free    0.0       Everyone
# 3   215644   25M  50,000,000+  Free    0.0           Teen
# 4      967  2.8M     100,000+  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
google_free.shape
# Out:
# (8903, 13)

# %% [markdown]
# # Frequencies by Genre

# %% [markdown]
# Apple Free Dataset

# %%
apple_free['prime_genre'].value_counts()/len(apple_free['prime_genre'])
# Out:
# prime_genre
# Games                0.556460
# Entertainment        0.082347
# Photo & Video        0.041174
# Social Networking    0.035256
# Education            0.032544
# Shopping             0.029832
# Utilities            0.026874
# Lifestyle            0.023176
# Finance              0.020710
# Sports               0.019477
# Health & Fitness     0.018738
# Music                0.016519
# Book                 0.016272
# Productivity         0.015286
# News                 0.014300
# Travel               0.013807
# Food & Drink         0.010602
# Weather              0.007643
# Business             0.004931
# Reference            0.004931
# Navigation           0.004931
# Catalogs             0.002219
# Medical              0.001972
# Name: count, dtype: float64

# %% [markdown]
# Google Play Free Dataset

# %%
google_free['Category'].value_counts()/len(google_free['Category'])
# Out:
# Category
# FAMILY                 0.185218
# GAME                   0.098506
# TOOLS                  0.084129
# BUSINESS               0.045827
# LIFESTYLE              0.039313
# PRODUCTIVITY           0.038863
# FINANCE                0.036842
# MEDICAL                0.035044
# SPORTS                 0.033809
# PERSONALIZATION        0.033135
# COMMUNICATION          0.032349
# HEALTH_AND_FITNESS     0.030664
# PHOTOGRAPHY            0.029428
# NEWS_AND_MAGAZINES     0.028305
# SOCIAL                 0.026508
# TRAVEL_AND_LOCAL       0.023251
# SHOPPING               0.022464
# BOOKS_AND_REFERENCE    0.021790
# DATING                 0.018533
# VIDEO_PLAYERS          0.017859
# MAPS_AND_NAVIGATION    0.014153
# EDUCATION              0.012917
# FOOD_AND_DRINK         0.012355
# ENTERTAINMENT          0.011232
# LIBRARIES_AND_DEMO     0.009323
# AUTO_AND_VEHICLES      0.009210
# HOUSE_AND_HOME         0.008312
# WEATHER                0.007975
# EVENTS                 0.007076
# ART_AND_DESIGN         0.006852
# PARENTING              0.006515
# COMICS                 0.006290
# BEAUTY                 0.005953
# Name: count, dtype: float64

# %%
google_free['Genres'].value_counts()/len(google_free['Genres'])
# Out:
# Genres
# Tools                          0.084017
# Entertainment                  0.060878
# Education                      0.053914
# Business                       0.045827
# Lifestyle                      0.039200
#                                  ...
# Strategy;Action & Adventure    0.000112
# Art & Design;Pretend Play      0.000112
# Arcade;Pretend Play            0.000112
# Entertainment;Education        0.000112
# Strategy;Creativity            0.000112
# Name: count, Length: 114, dtype: float64

# %% [markdown]
# Apple Dataset

# %%
apple['prime_genre'].value_counts()/len(apple['prime_genre'])
# Out:
# prime_genre
# Games                0.536612
# Entertainment        0.074337
# Education            0.062943
# Photo & Video        0.048492
# Utilities            0.034459
# Health & Fitness     0.025010
# Productivity         0.024733
# Social Networking    0.023204
# Lifestyle            0.020008
# Music                0.019175
# Shopping             0.016952
# Sports               0.015840
# Book                 0.015562
# Finance              0.014450
# Travel               0.011255
# News                 0.010421
# Weather              0.010004
# Reference            0.008893
# Food & Drink         0.008754
# Business             0.007920
# Navigation           0.006392
# Medical              0.003196
# Catalogs             0.001389
# Name: count, dtype: float64

# %% [markdown]
# Google Play Dataset

# %%
google['Category'].value_counts()/len(google['Category'])
# Out:
# Category
# FAMILY                 0.189668
# GAME                   0.099286
# TOOLS                  0.085620
# BUSINESS               0.043483
# MEDICAL                0.040895
# PERSONALIZATION        0.038927
# PRODUCTIVITY           0.038720
# LIFESTYLE              0.038203
# FINANCE                0.035718
# SPORTS                 0.033647
# COMMUNICATION          0.032612
# HEALTH_AND_FITNESS     0.029817
# PHOTOGRAPHY            0.029092
# NEWS_AND_MAGAZINES     0.026297
# SOCIAL                 0.024744
# BOOKS_AND_REFERENCE    0.022984
# TRAVEL_AND_LOCAL       0.022673
# SHOPPING               0.020913
# DATING                 0.017704
# VIDEO_PLAYERS          0.016875
# MAPS_AND_NAVIGATION    0.013562
# EDUCATION              0.012320
# FOOD_AND_DRINK         0.011595
# ENTERTAINMENT          0.010560
# AUTO_AND_VEHICLES      0.008800
# LIBRARIES_AND_DEMO     0.008697
# WEATHER                0.008179
# HOUSE_AND_HOME         0.007661
# EVENTS                 0.006626
# ART_AND_DESIGN         0.006626
# PARENTING              0.006212
# COMICS                 0.005798
# BEAUTY                 0.005487
# Name: count, dtype: float64

# %%
google['Genres'].value_counts()/len(google['Genres'])
# Out:
# Genres
# Tools                              0.085516
# Entertainment                      0.058081
# Education                          0.052800
# Business                           0.043483
# Medical                            0.040895
#                                      ...
# Art & Design;Pretend Play          0.000104
# Lifestyle;Pretend Play             0.000104
# Comics;Creativity                  0.000104
# Art & Design;Action & Adventure    0.000104
# Strategy;Creativity                0.000104
# Name: count, Length: 118, dtype: float64

# %% [markdown]
# ## Top Apps By Genre

# %%
apple['prime_genre'].unique()
# Out:
# array(['Games', 'Productivity', 'Weather', 'Shopping', 'Reference',
#        'Finance', 'Music', 'Utilities', 'Travel', 'Social Networking',
#        'Sports', 'Business', 'Health & Fitness', 'Entertainment',
#        'Photo & Video', 'Navigation', 'Education', 'Lifestyle',
#        'Food & Drink', 'News', 'Book', 'Medical', 'Catalogs'],
#       dtype=object)

# %%
google['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION'],
#       dtype=object)

# %% [markdown]
# Order Apple Store  By Number of Reviews

# %%
apple_sorted = apple.sort_values('rating_count_tot', ascending=False)

# %%
apple_sorted.head()
# Out:
#              id               track_name  size_bytes currency  price  \
# 16    284882215                 Facebook   389879808      USD    0.0
# 519   389801252                Instagram   113954816      USD    0.0
# 1346  529479190           Clash of Clans   116476928      USD    0.0
# 707   420009108               Temple Run    65921024      USD    0.0
# 7     284035177  Pandora - Music & Radio   130242560      USD    0.0
#
#       rating_count_tot  rating_count_ver  user_rating  user_rating_ver  \
# 16             2974676               212          3.5              3.5
# 519            2161558              1289          4.5              4.0
# 1346           2130805               579          4.5              4.5
# 707            1724546              3842          4.5              4.0
# 7              1126879              3594          4.0              4.5
#
#           ver cont_rating        prime_genre  sup_devices.num  \
# 16       95.0          4+  Social Networking               37
# 519     10.23         12+      Photo & Video               37
# 1346  9.24.12          9+              Games               38
# 707     1.6.2          9+              Games               40
# 7       8.4.1         12+              Music               37
#
#       ipadSc_urls.num  lang.num  vpp_lic
# 16                  1        29        1
# 519                 0        29        1
# 1346                5        18        1
# 707                 5         1        1
# 7                   4         1        1

# %% [markdown]
# Extract Top App For Each Genre and Save in New DataFrame

# %%
apple_top = pd.DataFrame()

# %%
apple_top['Genre'] = apple['prime_genre'].unique()

# %%
apple_top['App'] = ''
apple_top['Reviews'] = ''

# %%
for genre in apple_top['Genre']:
    apple_top.loc[apple_top['Genre'] == genre, 'App'] = apple_sorted.loc[apple_sorted['prime_genre'] == genre, 'track_name'].iloc[0]
    apple_top.loc[apple_top['Genre'] == genre, 'Reviews'] = apple_sorted.loc[apple_sorted['prime_genre'] == genre, 'rating_count_tot'].iloc[0]

# %%
apple_top
# Out:
#                 Genre                                                App  \
# 0               Games                                     Clash of Clans
# 1        Productivity                          Evernote - stay organized
# 2             Weather      The Weather Channel: Forecast, Radar & Alerts
# 3            Shopping   Groupon - Deals, Coupons & Discount Shopping App
# 4           Reference                                              Bible
# 5             Finance                                      Chase Mobile℠
# 6               Music                            Pandora - Music & Radio
# 7           Utilities               Google – Search made just for mobile
# 8              Travel                                       Google Earth
# 9   Social Networking                                           Facebook
# 10             Sports  ESPN: Get scores, news, alerts & watch live sp...
# 11           Business                                  Indeed Job Search
# 12   Health & Fitness     Calorie Counter & Diet Tracker by MyFitnessPal
# 13      Entertainment                                            Netflix
# 14      Photo & Video                                          Instagram
# 15         Navigation    Waze - GPS Navigation, Maps & Real-time Traffic
# 16          Education          Duolingo - Learn Spanish, French and more
# 17          Lifestyle     Zillow Real Estate - Homes for Sale & for Rent
# 18       Food & Drink                                          Starbucks
# 19               News                                            Twitter
# 20               Book        Kindle – Read eBooks, Magazines & Textbooks
# 21            Medical                        Baby Connect (Activity Log)
# 22           Catalogs      CPlus for Craigslist app - mobile classifieds
#
#     Reviews
# 0   2130805
# 1    161065
# 2    495626
# 3    417779
# 4    985920
# 5    233270
# 6   1126879
# 7    479440
# 8    446185
# 9   2974676
# 10   290996
# 11    38681
# 12   507706
# 13   308844
# 14  2161558
# 15   345046
# 16   162701
# 17   342969
# 18   303856
# 19   354058
# 20   252076
# 21     3483
# 22    13345

# %% [markdown]
# Order Google Play Dataset by Number of Installs

# %%
google_sorted = google

# %%
google_sorted['Installs'] = google_sorted['Installs'].str.replace('+','')
google_sorted['Installs'] = google_sorted['Installs'].str.replace(',','').astype(int)

# %%
google_sorted.head()
# Out:
#                                            App       Category  Rating  \
# 2544                                  Facebook         SOCIAL     4.1
# 336                         WhatsApp Messenger  COMMUNICATION     4.4
# 2545                                 Instagram         SOCIAL     4.5
# 335   Messenger – Text and Video Chat for Free  COMMUNICATION     4.0
# 1654                            Subway Surfers           GAME     4.5
#
#        Reviews                Size    Installs  Type  Price Content Rating  \
# 2544  78158306  Varies with device  1000000000  Free    0.0           Teen
# 336   69119316  Varies with device  1000000000  Free    0.0       Everyone
# 2545  66577313  Varies with device  1000000000  Free    0.0           Teen
# 335   56642847  Varies with device  1000000000  Free    0.0       Everyone
# 1654  27722264                 76M  1000000000  Free    0.0   Everyone 10+
#
#              Genres    Last Updated         Current Ver         Android Ver
# 2544         Social  August 3, 2018  Varies with device  Varies with device
# 336   Communication  August 3, 2018  Varies with device  Varies with device
# 2545         Social   July 31, 2018  Varies with device  Varies with device
# 335   Communication  August 1, 2018  Varies with device  Varies with device
# 1654         Arcade   July 12, 2018              1.90.0          4.1 and up

# %%
google_sorted = google_sorted.sort_values(['Installs','Reviews'], ascending=False)

# %% [markdown]
# Extract Top App by Category and Save Into New DataFrame

# %%
google_top = pd.DataFrame()

# %%
google_top['cat'] = google['Category'].unique()

# %%
google_top['app_name'] = ''
google_top['num_installs'] = ''
google_top['num_reviews'] = ''

# %%
for category in google_top['cat']:
    google_top.loc[google_top['cat'] == category, 'app_name'] = google_sorted.loc[google_sorted['Category'] == category, 'App'].iloc[0]
    google_top.loc[google_top['cat'] == category, 'num_installs'] = google_sorted.loc[google_sorted['Category'] == category, 'Installs'].iloc[0]
    google_top.loc[google_top['cat'] == category, 'num_reviews'] = google_sorted.loc[google_sorted['Category'] == category, 'Reviews'].iloc[0]

# %%
google_top
# Out:
#                     cat                                           app_name  \
# 0        ART_AND_DESIGN                              Sketch - Draw & Paint
# 1     AUTO_AND_VEHICLES      Android Auto - Maps, Media, Messaging & Voice
# 2                BEAUTY                      Beauty Camera - Selfie Camera
# 3   BOOKS_AND_REFERENCE                                  Google Play Books
# 4              BUSINESS             OfficeSuite : Free Office + PDF Editor
# 5                COMICS                         LINE WEBTOON - Free Comics
# 6         COMMUNICATION                                 WhatsApp Messenger
# 7                DATING                     Zoosk Dating App: Meet Singles
# 8             EDUCATION                     Duolingo: Learn Languages Free
# 9         ENTERTAINMENT                                  Google Play Games
# 10               EVENTS                         Ticketmaster Event Tickets
# 11              FINANCE                                         Google Pay
# 12       FOOD_AND_DRINK                                 Domino's Pizza USA
# 13   HEALTH_AND_FITNESS                                     Samsung Health
# 14       HOUSE_AND_HOME  Zillow: Find Houses for Sale & Apartments for ...
# 15   LIBRARIES_AND_DEMO                            MX Player Codec (ARMv7)
# 16            LIFESTYLE                                             Tinder
# 17                 GAME                                     Subway Surfers
# 18               FAMILY                                            Hay Day
# 19              MEDICAL                       My Calendar - Period Tracker
# 20               SOCIAL                                           Facebook
# 21             SHOPPING                           Wish - Shopping Made Fun
# 22          PHOTOGRAPHY                                      Google Photos
# 23               SPORTS                                        FIFA Soccer
# 24     TRAVEL_AND_LOCAL                          Maps - Navigate & Explore
# 25                TOOLS                                             Google
# 26      PERSONALIZATION   GO Launcher - 3D parallax Themes & HD Wallpapers
# 27         PRODUCTIVITY                                       Google Drive
# 28            PARENTING     Pregnancy Tracker & Countdown to Baby Due Date
# 29              WEATHER                 Weather & Clock Widget for Android
# 30        VIDEO_PLAYERS                                            YouTube
# 31   NEWS_AND_MAGAZINES                                        Google News
# 32  MAPS_AND_NAVIGATION  Waze - GPS, Maps, Traffic Alerts & Live Naviga...
#
#    num_installs num_reviews
# 0      50000000      215644
# 1      10000000      271920
# 2      10000000      113715
# 3    1000000000     1433233
# 4     100000000     1002861
# 5      10000000     1013635
# 6    1000000000    69119316
# 7      10000000      516801
# 8     100000000     6289924
# 9    1000000000     7165362
# 10      5000000       40113
# 11    100000000      347838
# 12     10000000     1032935
# 13    500000000      480208
# 14     10000000      417907
# 15     10000000      332083
# 16    100000000     2789775
# 17   1000000000    27722264
# 18    100000000    10053186
# 19      5000000      156410
# 20   1000000000    78158306
# 21    100000000     6210998
# 22   1000000000    10858556
# 23    100000000     3909032
# 24   1000000000     9235155
# 25   1000000000     8033493
# 26    100000000     7464996
# 27   1000000000     2731171
# 28     10000000      658087
# 29     50000000     2371543
# 30   1000000000    25655305
# 31   1000000000      877635
# 32    100000000     7232629
